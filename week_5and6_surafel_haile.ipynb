# %% [markdown]
# <a href="https://colab.research.google.com/github/surafelmeharihaile-ai/Data110/blob/main/week_5and6_surafel_haile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# Task 1: Explain why these columns are important for your analysis.
#
# ---
#
#
#
# These columns detail some info on the passengers. This helps us creat a distribution graph on the various information given(age, class, sex,etc...).This allows us to compare distribution graph of the respective columns. It's also useful to show the connection that exists between the different variables. We will be using either the histograms and KDE plots to showcase and compare distributions.

# %% [markdown]
# Task 2: Histogram and KDE of fare
#
# ---

# %% [markdown]
# Histogram :

# %%
sns.set_style('dark')
sns.histplot(titanic['fare'], shrink=1, color='c',edgecolor='k')
plt.title('Fare Distribution')
plt.xlabel('Fare')
plt.ylabel('Count')
plt.xlim(0,280)
plt.ylim(0,350)
plt.xticks([0,20,40,60,80,100,120,140,160,180,200,220,240])
plt.yticks([0,40,80,120,160,200,240,280,320])
plt.tight_layout()
plt.show()

# %% [markdown]
# KDE:
#
# ---

# %%
sns.kdeplot(titanic['fare'], fill=True, color='c')
plt.title('Fare Distribution')
plt.xlabel('Fare')
plt.ylabel('Count')
plt.xlim(0,560)
plt.show()

# %% [markdown]
# Task 3: Fare and survival distribution comparison
#
# ---

# %%
sns.kdeplot(data=titanic, x='fare', hue='survived', fill=True, palette='viridis')
plt.title('Fare Distribution by Survival')
plt.xlabel('Fare')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# Task 4: Box plots across multiple groups
#
# ---

# %%
sns.boxplot(data=titanic, x='pclass', y='fare', hue='sex',palette='dark:red')
plt.title('Fare Distribution by Passenger Class and Sex')
plt.xlabel('Passenger Class')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# As expected, passengers in pclass 1 generally paid higher fares than those in pclass 2, who in turn paid more than those in pclass 3. This indicates a clear correlation between ticket class and fare. Within pclass 1, the fares are generally much higher and have a wider spread compared to pclass 2 and 3. For pclass 1 and 2, women generally paid slightly higher fares than men, although this difference is more pronounced in pclass 1. In pclass 3, the fare distributions for male and female passengers are close to each other, with slightly more outliers for higher fares among females.

# %% [markdown]
# Task 5:Violin (age by sex).
#
# ---

# %%
sns.violinplot(data=titanic, x='sex', y='age')
plt.title('Age Distribution by Sex')
plt.xlabel('Sex')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# Here, we see that most passengers are probably around 20 and 40 years old considering the width of the violin plot. At the tails we can assume there is fewer peeople of the age that corresponds (70 and 80 year olds).

# %% [markdown]
# Task 6:  Strip (detail on top of violin or boxplot).
#
# ---

# %%
sns.violinplot(data=titanic, x='sex', y='age', inner=None, color=".8")
sns.stripplot(data=titanic, x='sex', y='age', jitter=0.2, color='0.25')
plt.title('Age Distribution by Sex with Individual Observations')
plt.xlabel('Sex')
plt.ylabel('Age')
plt.show()

# %% [markdown]
#  While the violin plot shows density, the stripplot clearly highlights distinct clusters of passengers at certain ages. For instance, there's a denser groupings in the late 20s and early 30s for both sexes.
#  The violin plot provides a smoothed estimate of the distribution. The individual points show the actual spread and where the data is truly sparse or dense. For example, areas where the violin plot is thin but still present might have very few actual data points, which is made explicit by the stripplot.
#  While the violin plot might hint at outliers through its tails, the stripplot makes individual outliers stand out distinctly. For example, the oldest passengers (in their 70s and 80s) for both males and females are clearly visible as individual dots far from the main body of the distribution.      The stripplot can reveal specific ages or age ranges where there were no passengers, creating visible gaps in the distribution that the violin plot might obscure.
