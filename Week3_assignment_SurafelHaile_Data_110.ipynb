# %% [markdown]
# <a href="https://colab.research.google.com/github/surafelmeharihaile-ai/Data110/blob/main/Week3_assignment_SurafelHaile_Data_110.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Part 1:** Practice

# %% [markdown]
# Simple Line Plots

# %%
x = np.linspace(0, 10, 1000)
plt.plot(x, np.sin(x))
plt.show()

# %% [markdown]
# np.sin(x) and np,cos(x)

# %%
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x))
plt.show()

# %% [markdown]
# Line colors and styles.

# %% [markdown]
# SIN (X-0):

# %%
plt.plot(x, np.sin(x-0),color="green",linestyle="dotted")
plt.show()

# %% [markdown]
# SIN (X+1):

# %%
plt.plot(x, x + 0, linestyle='dashed', color='red')
plt.plot(x, x + 1, linestyle='dashdot', color='green')
plt.show()

# %% [markdown]
# Lines and colors combined:

# %%
plt.plot(x, x + 0, '-b')
plt.plot(x, x + 1, '--p')
plt.plot(x, x + 2, '-.r')
plt.show()

# %% [markdown]
# Adjusting the Plot: Axes Limits

# %%
plt.plot(x, np.sin(x))

plt.xlim(0, 11)
plt.ylim(-2.5, 2.5)
# Out:
# (-2.5, 2.5)

# %% [markdown]
# reverse limit edit :

# %%
plt.plot(x, np.sin(x))

plt.xlim(11, 0)
plt.ylim(2.2, -2.2)
# Out:
# (2.2, -2.2)

# %% [markdown]
# plt.axis:

# %%
plt.plot(x, np.sin(x))
plt.axis("off")
# Out:
# (np.float64(-0.5),
#  np.float64(10.5),
#  np.float64(-1.0999971452300779),
#  np.float64(1.099999549246729))

# %%
plt.plot(x, np.sin(x))
plt.axis('square')
# Out:
# (np.float64(-0.5),
#  np.float64(10.5),
#  np.float64(-1.0999971452300779),
#  np.float64(9.900002854769923))

# %% [markdown]
# Labeling Plots:

# %%
plt.plot(x, np.cos(x),"--b" ,label="cos(x)")
plt.plot(x, np.sin(x),"-c" ,label="sin(x)")
plt.axis('square')

plt.legend()
plt.show()

# %% [markdown]
# Explain the difference between x as domain vs. as an index?
#
# X as a domain represents a possible input value of the funtion np.sin(X) or cos (x). While x as a index represents the position of a data point within the graph.

# %% [markdown]
# Part 2: Practice

# %%
plt.style.use('seaborn-v0_8-dark')

# %%
x=np.linspace(0,20,50)
y=np.cos(x)
plt.plot(x,y,"-p",color="b",linewidth=2,markerfacecolor="white",markeredgecolor="black")
plt.ylim(-2.5,2.5)
plt.show()

# %%
rng = np.random.default_rng(0)
n = 100
x = rng.normal(0, 1, n)
y = 0.0*x + rng.normal(0, 0, n)
size = 40 + 60*(rng.random(n))

# %%
plt.scatter(x, y, s=10, alpha=0.7,color="r")
plt.title('Practice Scatter Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# Part 3: assignment

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1: Setup and Styles

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# 2:Basic line Plot

# %%
x=np.linspace(-2,4,10)
y=x**2-2*x+1
plt.plot(x,y)
plt.show()

# %% [markdown]
# 3: Multiple lines

# %%
x=np.linspace(-2,4,10)
y1=x**3
y2=np.exp(x)
y3=np.log(x, where = x>0)
plt.plot(x,y1,label='fx')
plt.plot(x,y2,label='gx')
plt.plot(x,y3,label='hx')
plt.legend()
plt.show()

# %% [markdown]
# 4:Styling lines

# %%
x=np.linspace(-2,4,10)
y1=x**2
y2=x**3
y3=x**4
y4=x**5
plt.plot(x,y1,label='fx',color='r')
plt.plot(x,y2,label='gx',color=(1.0,0.2,0.3))
plt.plot(x,y3,label='hx',color='green')
plt.plot(x,y4,label='ix',color='b')
plt.legend()
plt.show()

# %% [markdown]
# 5:Axes limits and Scaling

# %%
x=np.linspace(-10,10,10)
y=1/x**2+1
plt.plot(x,y)
plt.axis('tight')
plt.xlim(-5,5)
plt.ylim(-5,5)
plt.show()

# %% [markdown]
# 6: Labels and Legends

# %%
x=np.linspace(-10,10,10)
y1=np.square(x)
y2=x**1/3
plt.plot(x,y1,label='fx')
plt.plot(x,y2,label='gx')
plt.legend(loc = "upper right")
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# 7: Basic scatter plot

# %%
x=np.random.rand(50)
y=np.random.rand(50)
plt.plot(x,y,marker="o")
plt.show()

# %%
x=np.random.rand(50)
y=np.random.rand(50)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# 8: Customizing Scatter Plots

# %%
x=np.linspace(0, 4*np.pi)
y=np.sin(x)
plt.plot(x,y,marker="o",markersize=7,markerfacecolor='w',markeredgecolor='k')
plt.show()

# %% [markdown]
# 9: Combined Plot

# %% [markdown]
# 10: Custom Plot with Alternative Style

# %% [markdown]
# 11:Style Comparison
