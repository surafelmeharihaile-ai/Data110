# %% [markdown]
# <a href="https://colab.research.google.com/github/surafelmeharihaile-ai/Data110/blob/main/week_7_surafel_haile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Load the penguins dataset from seaborn
penguins = sns.load_dataset('penguins')

# Display the first few rows of the dataset
print(penguins.head())
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
plt.scatter(penguins['bill_length_mm'], penguins['bill_depth_mm'])
plt.xlabel('Bill Length (mm)')
plt.ylabel('Bill Depth (mm)')
plt.title('Bill Length vs. Bill Depth')
plt.show()

# %%
# Set figure size
plt.figure(figsize=(8, 5))

# Scatter plot (manually colored)
plt.scatter(penguins["bill_length_mm"], penguins["bill_depth_mm"], color="dodgerblue", alpha=0.6, edgecolors="black", label="Data Points")

# Regression line
sns.regplot(data=penguins, x="bill_length_mm", y="bill_depth_mm", scatter=False, color="red", ci=None, label="Regression Line")

# Labels and title
plt.xlabel("Bill Length (mm)", fontsize=12)
plt.ylabel("Bill Depth (mm)", fontsize=12)
plt.title("Penguin Bill Measurements with Regression", fontsize=14)

# Add legend
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# Task 1: Bill Lenght vs Flipper Lenght

# %%
plt.scatter(penguins['bill_length_mm'], penguins['flipper_length_mm'])
plt.xlabel('Bill Length (mm)')
plt.ylabel('flipper Length (mm)')
plt.title('Bill Length vs. Flipper Length')
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.scatter(penguins["bill_length_mm"], penguins["flipper_length_mm"], color="dodgerblue", alpha=0.6, edgecolors="black", label="Data Points")

sns.regplot(data=penguins, x="bill_length_mm", y="flipper_length_mm", scatter=False, color="red", ci=None, label="Regression Line")

plt.xlabel("Bill Length (mm)", fontsize=12)
plt.ylabel("flipper Length (mm)", fontsize=12)
plt.title("Penguin Bill Measurements with Regression", fontsize=14)

plt.legend()
plt.show()

# %% [markdown]
# Task 2 : Bill Length vs. Body Mass

# %%
plt.scatter(penguins['bill_length_mm'], penguins['body_mass_g'])
plt.xlabel('Bill Length (mm)')
plt.ylabel(' Body Mass (g)')
plt.title('Bill Length vs. Body Mass')
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.scatter(penguins["bill_length_mm"], penguins["body_mass_g"], color="dodgerblue", alpha=0.6, edgecolors="black", label="Data Points")

sns.regplot(data=penguins, x="bill_length_mm", y="body_mass_g", scatter=False, color="red", ci=None, label="Regression Line")

plt.xlabel("Bill Length (mm)", fontsize=12)
plt.ylabel("Body mass (mm)", fontsize=12)
plt.title("Penguin Bill Measurements with Regression", fontsize=14)

plt.legend()
plt.show()

# %% [markdown]
# Taks 3:  Make 3 subplots — scatter + regression — for each species separately

# %%
penguins_adeile=penguins[penguins['species']=='Adelie']
penguins['species'].unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %% [markdown]
# Adelie:

# %%
print(penguins.isnull().sum())
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
adelie_bill_length = penguins[penguins['species'] == 'Adelie']['bill_length_mm']


print(adelie_bill_length)
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 147    36.6
# 148    36.0
# 149    37.8
# 150    36.0
# 151    41.5
# Name: bill_length_mm, Length: 152, dtype: float64

# %%
adelie_body_mass = penguins[penguins['species'] == 'Adelie']['body_mass_g']
print(adelie_body_mass)
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 3         NaN
# 4      3450.0
#         ...
# 147    3475.0
# 148    3450.0
# 149    3750.0
# 150    3700.0
# 151    4000.0
# Name: body_mass_g, Length: 152, dtype: float64

# %%
adelie_flipper_length = penguins[penguins['species'] == 'Adelie']['flipper_length_mm']
print(adelie_flipper_length)
# Out:
# 0      181.0
# 1      186.0
# 2      195.0
# 3        NaN
# 4      193.0
#        ...
# 147    184.0
# 148    195.0
# 149    193.0
# 150    187.0
# 151    201.0
# Name: flipper_length_mm, Length: 152, dtype: float64

# %% [markdown]
# Subplots:

# %%
plt.scatter(adelie_bill_length, adelie_body_mass)
plt.xlabel('Adelie Bill Length (mm)')
plt.ylabel('Adelie Body mass (g)')
plt.title('Adelie Bill length vs Body mass')
plt.show()

# %%
plt.scatter(adelie_bill_length, adelie_flipper_length)
plt.xlabel('Adelie Bill Length (mm)')
plt.ylabel('Adelie flipper length (mm)')
plt.title('Adelie Bill length vs  Flipper length')
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.scatter(adelie_bill_length, adelie_body_mass, color="dodgerblue", alpha=0.6, edgecolors="black", label="Data Points")

sns.regplot(data=penguins, x="bill_length_mm", y="body_mass_g", scatter=False, color="red", ci=None, label="Regression Line")

plt.xlabel("Adelie Bill Length (mm)", fontsize=12)
plt.ylabel("Adelie Body Mass (g)", fontsize=12)
plt.title("Penguin Bill Measurements with Regression", fontsize=14)

plt.legend()
plt.show()

# %% [markdown]
# Chinstrap :

# %%
print(penguins.isnull().sum())
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
chinstap_bill_length = penguins[penguins['species'] == 'Chinstrap']['bill_length_mm']
print(chinstap_bill_length)
# Out:
# 152    46.5
# 153    50.0
# 154    51.3
# 155    45.4
# 156    52.7
#        ...
# 215    55.8
# 216    43.5
# 217    49.6
# 218    50.8
# 219    50.2
# Name: bill_length_mm, Length: 68, dtype: float64

# %%
chinstrap_body_mass = penguins[penguins['species'] == 'Chinstrap']['body_mass_g']
print(chinstrap_body_mass)
# Out:
# 152    3500.0
# 153    3900.0
# 154    3650.0
# 155    3525.0
# 156    3725.0
#         ...
# 215    4000.0
# 216    3400.0
# 217    3775.0
# 218    4100.0
# 219    3775.0
# Name: body_mass_g, Length: 68, dtype: float64

# %%
chinstrap_flipper_length = penguins[penguins['species'] == 'Chinstrap']['flipper_length_mm']
print(chinstrap_flipper_length)
# Out:
# 152    192.0
# 153    196.0
# 154    193.0
# 155    188.0
# 156    197.0
#        ...
# 215    207.0
# 216    202.0
# 217    193.0
# 218    210.0
# 219    198.0
# Name: flipper_length_mm, Length: 68, dtype: float64

# %% [markdown]
# Subplots:

# %%
plt.scatter(chinstap_bill_length, chinstrap_body_mass)
plt.xlabel('Chinstrap Bill Length (mm)')
plt.ylabel('Chinstrap Body mass (g)')
plt.title('Chinstrap Bill length vs Body mass')
plt.show()

# %%
plt.scatter(chinstap_bill_length, chinstrap_flipper_length)
plt.xlabel('Chinstrap Bill Length (mm)')
plt.ylabel('Chinstrap flipper length (mm)')
plt.title('Chinstrap Bill length vs  Flipper length')
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.scatter(chinstap_bill_length, chinstrap_body_mass, color="dodgerblue", alpha=0.6, edgecolors="black", label="Data Points")

sns.regplot(data=penguins, x="bill_length_mm", y="body_mass_g", scatter=False, color="red", ci=None, label="Regression Line")

plt.xlabel("Chinstrap Bill Length (mm)", fontsize=12)
plt.ylabel("Chinstrap Body Mass (g)", fontsize=12)
plt.title("Penguin Bill Measurements with Regression", fontsize=14)

plt.legend()
plt.show()

# %% [markdown]
#  Gentoo:

# %%
print(penguins.isnull().sum())
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
Gentoo_bill_length = penguins[penguins['species'] == 'Gentoo']['bill_length_mm']
print(Gentoo_bill_length)
# Out:
# 220    46.1
# 221    50.0
# 222    48.7
# 223    50.0
# 224    47.6
#        ...
# 339     NaN
# 340    46.8
# 341    50.4
# 342    45.2
# 343    49.9
# Name: bill_length_mm, Length: 124, dtype: float64

# %%
Gentoo_body_mass = penguins[penguins['species'] == 'Gentoo']['body_mass_g']
print(Gentoo_body_mass)
# Out:
# 220    4500.0
# 221    5700.0
# 222    4450.0
# 223    5700.0
# 224    5400.0
#         ...
# 339       NaN
# 340    4850.0
# 341    5750.0
# 342    5200.0
# 343    5400.0
# Name: body_mass_g, Length: 124, dtype: float64

# %%
Gentoo_flipper_length = penguins[penguins['species'] == 'Gentoo']['flipper_length_mm']
print(Gentoo_flipper_length)
# Out:
# 220    211.0
# 221    230.0
# 222    210.0
# 223    218.0
# 224    215.0
#        ...
# 339      NaN
# 340    215.0
# 341    222.0
# 342    212.0
# 343    213.0
# Name: flipper_length_mm, Length: 124, dtype: float64

# %% [markdown]
# Subplots:

# %%
plt.scatter(Gentoo_bill_length, Gentoo_body_mass)
plt.xlabel('Gentoo Bill Length (mm)')
plt.ylabel('Gentoo Body mass (g)')
plt.title('Gentoo Bill length vs Body mass')
plt.show()

# %%
plt.scatter(Gentoo_bill_length, Gentoo_flipper_length)
plt.xlabel('Gentoo Bill Length (mm)')
plt.ylabel('Gentoo flipper length (mm)')
plt.title('Gentoo Bill length vs  Flipper length')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.scatter(Gentoo_bill_length, Gentoo_body_mass, color="dodgerblue", alpha=0.6, edgecolors="black", label="Data Points")

sns.regplot(data=penguins  , x="bill_length_mm", y="body_mass_g", scatter=False, color="red", ci=None)

plt.xlabel("Gentoo Bill Length (mm)", fontsize=12)
plt.ylabel("Gentoo Body Mass (g)", fontsize=12)
plt.title("Penguin Bill Measurements with Regression", fontsize=14)
plt.legend()
plt.show()

# %% [markdown]
# Seaborn Pairplot:

# %%
sns.pairplot(penguins)

# %%
sns.pairplot(penguins, hue="species", diag_kind="kde")

plt.show()

# %%
sns.pairplot(penguins, hue="island", diag_kind="kde")

plt.show()

# %%
sns.pairplot(penguins, hue="species", markers=["o", "s", "D"])


plt.show()

# %%
sns.pairplot(penguins, hue="species", height=3.5)

# %%
sns.pairplot(penguins, hue="species", palette="coolwarm")

# %% [markdown]
# Task 4 : Pairplot remix
