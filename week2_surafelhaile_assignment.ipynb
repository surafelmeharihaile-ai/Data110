# %% [markdown]
# <a href="https://colab.research.google.com/github/surafelmeharihaile-ai/Data110/blob/main/week2_surafelhaile_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Reben80/Data110-21843--fall25/refs/heads/main/dataset/happiness_2017.csv')

# %% [markdown]
# Part A Task

# %% [markdown]
# Scatter plot 1

# %%
plt.scatter(df['Social support'], df['HappinessScore'], color='green')
plt.xlabel('Social support')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Social support')
plt.show()

# %% [markdown]
# Scatter plot 2

# %%
plt.scatter(df['Freedom to make life choices'], df['HappinessScore'], color='black')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Freedom to make life choices')
plt.show()

# %% [markdown]
# Scatter plot 3

# %%
plt.scatter(df['Generosity'], df['HappinessScore'], color='yellow')
plt.xlabel('Generosity')
plt.ylabel('Happiness Score')
plt.title('Happiness Score vs Generosity')
plt.show()

# %% [markdown]
# Extra Task : NON meaningful relationship
# scatter plots

# %%
plt.scatter(df['Perceptions of corruption'], df['Generosity'], color='Pink')
plt.xlabel('Generosity')
plt.ylabel('Perceptions of corruption')
plt.title('Perceptions of corruption vs Generosity')
plt.show()

# %%
plt.scatter(df['Perceptions of corruption'], df['Healthy life expectancy at birth'], color='red')
plt.xlabel('Healthy life expectancy at birth')
plt.ylabel('Perceptions of corruption')
plt.title('Perceptions of corruption vs Healthy life expectancy at birth')
plt.show()

# %% [markdown]
# Part B Task

# %%
x = [10, 8, 13, 9, 11, 14, 6, 4, 12, 7, 5]
y1 = [8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68]
y2 = [9.14, 8.14, 8.74, 8.77, 9.26, 8.10, 6.13, 3.10, 9.13, 7.26, 4.74]
y3 = [7.46, 6.77, 12.74, 7.11, 7.81, 8.84, 6.08, 5.39, 8.15, 6.42, 5.73]
x4 = [8, 8, 8, 8, 8, 8, 8, 19, 8, 8, 8]
y4 = [6.58, 5.76, 7.71, 8.84, 8.47, 7.04, 5.25, 12.50, 5.56, 7.91, 6.89]

# %%
plt.scatter(x, y2)

# %%
m, b = np.polyfit(x, y2, 1)

# %%
regression_line = m * np.array(x) + b

# %%
plt.scatter(x, y2)
plt.plot(x, regression_line,color='red')
plt.xlabel('x')
plt.ylabel('y2')
# Out:
# Text(0, 0.5, 'y2')

# %%
plt.scatter(x, y3)

# %%
m, b = np.polyfit(x, y3, 1)

# %%
regression_line = m * np.array(x) + b

# %%
plt.scatter(x, y3)
plt.plot(x, regression_line,color='red')
plt.xlabel('x')
plt.ylabel('y3')
# Out:
# Text(0, 0.5, 'y3')

# %%
plt.scatter(x, y4)

# %%
m, b = np.polyfit(x, y4, 1)

# %%
regression_line = m * np.array(x) + b

# %%
plt.scatter(x, y4)
plt.plot(x, regression_line,color='red')
plt.xlabel('x4')
plt.ylabel('y4')
# Out:
# Text(0, 0.5, 'y4')

# %%
plt.scatter(x4, y4)

# %%
m, b = np.polyfit(x4, y4, 1)

# %%
regression_line = m * np.array(x) + b

# %%
plt.scatter(x4, y4)
plt.plot(x, regression_line,color='red')
plt.xlabel('x4')
plt.ylabel('y4')
# Out:
# Text(0, 0.5, 'y4')

# %% [markdown]
# Reflection Questions:
#
# 1. Althought the dataset has similar statistics,when ploted,we see that the satter plot between the variables yields different relationships.
# 2. The regression line for dataset x4, y4 seems to establish a positive relationship between the two variables. Unlike x,y3 and x,y4.
# 3. Visualizing data helps us see details that we might have, otherwise missed. For example: the positive or negative relation that exists between the variables.
